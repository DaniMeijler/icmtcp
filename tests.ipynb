# %%
from src.icmtcp_client import ICMTCPClient
from src.utils.icmp_packet import ICMPPacket
from src.utils import tcp_icmp_encapsulator

# %%
tcp_data = b"a"*5000

# %%
fragments = tcp_icmp_encapsulator.encapsule_tcp_data(tcp_data, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fragments = encapsule_tcp_data(tcp_data, 4)
#
# NameError: name 'encapsule_tcp_data' is not defined
