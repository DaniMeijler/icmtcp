# %%
from src.icmtcp_client import ICMTCPClient
from src.utils.icmp_packet import ICMPPacket

# %%
packet = ICMPPacket(type=0, code=0, id=60, seq_num=0, payload=b'Hello, ICMP!')

# %%
packet_bytes = packet.raw_packet()
packet_bytes
# Out:
# b'\x00\x00(J\x00\x00\x00\x00Hello, ICMP!'

# %%
new_packet = ICMPPacket()
new_packet.from_bytes(packet_bytes)

# %%
new_packet.id
# Out:
# 0

# %%
new_packet.payload
# Out:
# b''
